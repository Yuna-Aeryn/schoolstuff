# %% [markdown]
# 1. LogisticRegression, Knn, decisiontree, randomforest

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cols = ["fixed acidity", "volatile acidity", "citric acid", "residual sugar", "chlorides", "free sulfur dioxide", "total sulfur dioxide", "density", "pH", "sulphates", "alcohol", "quality"]
df = pd.read_csv("/content/drive/MyDrive/College/3-2/04. 기계학습프로그래밍/CODE/4/wine+quality/winequality_white_dataframe.csv", header=0, names=cols)
display(df.head())
df = df.dropna()

X = df.drop(columns=["quality"])
y = df["quality"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

X_train.shape, X_test.shape, y_train.shape, y_test.shape

kn = KNeighborsClassifier()
dt = DecisionTreeClassifier(random_state=42)
rf = RandomForestClassifier(n_estimators=200, random_state=42)
lr = LogisticRegression(max_iter=500)

kn.fit(X_train, y_train)
dt.fit(X_train, y_train)
rf.fit(X_train, y_train)
lr.fit(X_train, y_train)

kn_y_pred = kn.predict(X_test)
dt_y_pred = dt.predict(X_test)
rf_y_pred = rf.predict(X_test)
lr_y_pred = lr.predict(X_test)

kn_acc = accuracy_score(y_test, kn_y_pred)
dt_acc = accuracy_score(y_test, dt_y_pred)
rf_acc = accuracy_score(y_test, rf_y_pred )
lr_acc = accuracy_score(y_test, lr_y_pred)

print("=== KNN Test Accuracy ===")
print(f"KNN : {kn_acc:.4f}")
print (confusion_matrix(y_test,kn_y_pred))

print("=== DT Test Accuracy ===")
print(f"Decision Tree : {dt_acc:.4f}")
print (confusion_matrix(y_test,dt_y_pred))

print("=== RF Test Accuracy ===")
print(f"Random Forest : {rf_acc:.4f}")
print (confusion_matrix(y_test,rf_y_pred))

print("=== LR Test Accuracy ===")
print(f"Logistic Reg. : {lr_acc:.4f}")
print (confusion_matrix(y_test,lr_y_pred))
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6
# === KNN Test Accuracy ===
# KNN : 0.4449
# [[  0   0   1   3   0   0   0]
#  [  0   2  18  12   1   0   0]
#  [  0   9 136 128  17   1   0]
#  [  0   7 128 246  57   2   0]
#  [  0   0  24 103  44   5   0]
#  [  0   0   6  13   8   8   0]
#  [  0   0   0   1   0   0   0]]
# === DT Test Accuracy ===
# Decision Tree : 0.5908
# [[  0   1   2   1   0   0   0]
#  [  0   9  14   8   1   1   0]
#  [  0  15 174  81  14   7   0]
#  [  1  12  81 275  62   9   0]
#  [  0   1  15  55 100   5   0]
#  [  0   1   1   6   6  21   0]
#  [  0   0   0   0   1   0   0]]
# === RF Test Accuracy ===
# Random Forest : 0.6776
# [[  0   0   1   3   0   0   0]
#  [  0   7  18   8   0   0   0]
#  [  0   3 191  97   0   0   0]
#  [  0   1  50 362  27   0   0]
#  [  0   0   4  87  85   0   0]
#  [  0   0   1   8   7  19   0]
#  [  0   0   0   0   1   0   0]]
# === LR Test Accuracy ===
# Logistic Reg. : 0.5163
# [[  0   0   1   3   0   0   0]
#  [  0   0  19  14   0   0   0]
#  [  0   0 137 153   1   0   0]
#  [  0   0  81 347  12   0   0]
#  [  0   0  16 138  22   0   0]
#  [  0   0   7  21   7   0   0]
#  [  0   0   0   0   1   0   0]]
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# 2. DL- FC (winedata)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
from tensorflow import keras
from sklearn.datasets import load_breast_cancer
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD, Adam
from sklearn.metrics import classification_report, confusion_matrix

df = pd.read_csv("/content/drive/MyDrive/College/3-2/04. 기계학습프로그래밍/CODE/4/wine+quality/winequality_white_dataframe.csv", index_col=0)
df = df.dropna()
display(df.head())

X = df.drop(columns=["quality"])
y = df["quality"]

Y = pd.get_dummies(y).values
X = X.values
X_train,X_test, y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

model = Sequential()
model.add(Dense(10,input_shape=(10,),activation='relu'))
model.add(Dense(8,activation='relu'))
model.add(Dense(6,activation='relu'))
model.add(Dense(2,activation='softmax'))
model.compile(Adam(learning_rate=0.04),'binary_crossentropy',metrics=['accuracy'])

# 차원수 문제 빨리 해결할것
model_history=model.fit(x=X_train, y=y_train, epochs=30, batch_size=32,validation_data= (X_test,y_test))
y_pred = model.predict(X_test)
y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)

loss = model_history.history['loss']
val_loss = model_history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
#                volatile acidity  citric acid  residual sugar  chlorides  \
# fixed acidity
# 7.0                        0.27         0.36            20.7      0.045
# 6.3                        0.30         0.34             1.6      0.049
# 8.1                        0.28         0.40             6.9      0.050
# 7.2                        0.23         0.32             8.5      0.058
# 7.2                        0.23         0.32             8.5      0.058
#
#                free sulfur dioxide  total sulfur dioxide  density    pH  \
# fixed acidity
# 7.0                           45.0                 170.0   1.0010  3.00
# 6.3                           14.0                 132.0   0.9940  3.30
# 8.1                           30.0                  97.0   0.9951  3.26
# 7.2                           47.0                 186.0   0.9956  3.19
# 7.2                           47.0                 186.0   0.9956  3.19
#
#                sulphates  alcohol  quality
# fixed acidity
# 7.0                 0.45      8.8        6
# 6.3                 0.49      9.5        6
# 8.1                 0.44     10.1        6
# 7.2                 0.40      9.9        6
# 7.2                 0.40      9.9        6
# Epoch 1/30
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2709798795.py in <cell line: 0>()
#      32 model.compile(Adam(learning_rate=0.04),'binary_crossentropy',metrics=['accuracy'])
#      33
# ---> 34 model_history=model.fit(x=X_train, y=y_train, epochs=30, batch_size=32,validation_data= (X_test,y_test))
#      35 y_pred = model.predict(X_test)
#      36 y_test_class = np.argmax(y_test,axis=1)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/nn.py in binary_crossentropy(target, output, from_logits)
#     781     for e1, e2 in zip(target.shape, output.shape):
#     782         if e1 is not None and e2 is not None and e1 != e2:
# --> 783             raise ValueError(
#     784                 "Arguments `target` and `output` must have the same shape. "
#     785                 "Received: "
#
# ValueError: Arguments `target` and `output` must have the same shape. Received: target.shape=(None, 7), output.shape=(None, 2)

# %% [markdown]
# 3. DL-FC (breastcancerdata)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
from tensorflow import keras
from sklearn.datasets import load_breast_cancer
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD, Adam
from sklearn.metrics import classification_report, confusion_matrix

df = pd.read_csv("/content/drive/MyDrive/College/3-2/04. 기계학습프로그래밍/CODE/2주차/breast_cancer.csv", index_col=0)
df = df.dropna()
display(df.head())

X = df.drop(columns=["label"])
y = df["label"]

Y = pd.get_dummies(y).values
X = X.values
X_train,X_test, y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

model = Sequential()
model.add(Dense(10,input_shape=(30,),activation='relu'))
model.add(Dense(8,activation='relu'))
model.add(Dense(6,activation='relu'))
model.add(Dense(2,activation='softmax'))
model.compile(Adam(learning_rate=0.04),'binary_crossentropy',metrics=['accuracy'])

model_history=model.fit(x=X_train, y=y_train, epochs=30, batch_size=32,validation_data= (X_test,y_test))
y_pred = model.predict(X_test)
y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)

loss = model_history.history['loss']
val_loss = model_history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  label
# 0          0.4601                  0.11890      0
# 1          0.2750                  0.08902      0
# 2          0.3613                  0.08758      0
# 3          0.6638                  0.17300      0
# 4          0.2364                  0.07678      0
#
# [5 rows x 31 columns]
# Epoch 1/30
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.6822 - loss: 5.9615 - val_accuracy: 0.5877 - val_loss: 0.6805
# Epoch 2/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6133 - loss: 0.6678 - val_accuracy: 0.5877 - val_loss: 0.6867
# Epoch 3/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6278 - loss: 0.6630 - val_accuracy: 0.5877 - val_loss: 0.6863
# Epoch 4/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5910 - loss: 0.6834 - val_accuracy: 0.5877 - val_loss: 0.6872
# Epoch 5/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6363 - loss: 0.6588 - val_accuracy: 0.5877 - val_loss: 0.6844
# Epoch 6/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6443 - loss: 0.6518 - val_accuracy: 0.5877 - val_loss: 0.6826
# Epoch 7/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6137 - loss: 0.6689 - val_accuracy: 0.5877 - val_loss: 0.6858
# Epoch 8/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6486 - loss: 0.6496 - val_accuracy: 0.5877 - val_loss: 0.6811
# Epoch 9/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6499 - loss: 0.6517 - val_accuracy: 0.5877 - val_loss: 0.6805
# Epoch 10/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6367 - loss: 0.6563 - val_accuracy: 0.5877 - val_loss: 0.6830
# Epoch 11/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6475 - loss: 0.6495 - val_accuracy: 0.5877 - val_loss: 0.6838
# Epoch 12/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6499 - loss: 0.6482 - val_accuracy: 0.5877 - val_loss: 0.6823
# Epoch 13/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6773 - loss: 0.6334 - val_accuracy: 0.5877 - val_loss: 0.6789
# Epoch 14/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6638 - loss: 0.6455 - val_accuracy: 0.5877 - val_loss: 0.6814
# Epoch 15/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6665 - loss: 0.6398 - val_accuracy: 0.5877 - val_loss: 0.6815
# Epoch 16/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6303 - loss: 0.6590 - val_accuracy: 0.5877 - val_loss: 0.6831
# Epoch 17/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6374 - loss: 0.6557 - val_accuracy: 0.5877 - val_loss: 0.6838
# Epoch 18/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6811 - loss: 0.6301 - val_accuracy: 0.5877 - val_loss: 0.6793
# Epoch 19/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6361 - loss: 0.6585 - val_accuracy: 0.5877 - val_loss: 0.6811
# Epoch 20/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6863 - loss: 0.6308 - val_accuracy: 0.5877 - val_loss: 0.6785
# Epoch 21/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6222 - loss: 0.6642 - val_accuracy: 0.5877 - val_loss: 0.6833
# Epoch 22/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5827 - loss: 0.6880 - val_accuracy: 0.5877 - val_loss: 0.6894
# Epoch 23/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6140 - loss: 0.6719 - val_accuracy: 0.5877 - val_loss: 0.6849
# Epoch 24/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6246 - loss: 0.6638 - val_accuracy: 0.5877 - val_loss: 0.6854
# Epoch 25/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6401 - loss: 0.6542 - val_accuracy: 0.5877 - val_loss: 0.6826
# Epoch 26/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6291 - loss: 0.6606 - val_accuracy: 0.5877 - val_loss: 0.6814
# Epoch 27/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6501 - loss: 0.6489 - val_accuracy: 0.5877 - val_loss: 0.6828
# Epoch 28/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6323 - loss: 0.6593 - val_accuracy: 0.5877 - val_loss: 0.6816
# Epoch 29/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6635 - loss: 0.6415 - val_accuracy: 0.5877 - val_loss: 0.6796
# Epoch 30/30
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6706 - loss: 0.6407 - val_accuracy: 0.5877 - val_loss: 0.6809
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7fe597dabec0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# WARNING:tensorflow:6 out of the last 12 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7fe597dabec0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        47
#            1       0.59      1.00      0.74        67
#
#     accuracy                           0.59       114
#    macro avg       0.29      0.50      0.37       114
# weighted avg       0.35      0.59      0.44       114
#
# [[ 0 47]
#  [ 0 67]]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# # New Section
